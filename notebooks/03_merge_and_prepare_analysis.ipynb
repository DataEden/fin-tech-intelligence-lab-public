# %%
# ============================================================
# Financial Intelligence Lab
# 03_merge_and_prepare_analysis.ipynb
#
# Purpose:
# Merge portfolio snapshots, portfolio summary, market notes,
# dividends, and Yahoo backfill prices into analysis-ready tables.
# ============================================================

from pathlib import Path
import pandas as pd

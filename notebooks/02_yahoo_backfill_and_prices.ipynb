# %%
# ============================================================
# Financial Intelligence Lab
# 02_yahoo_backfill.ipynb
#
# Purpose:
# Pull historical market data from Yahoo Finance for assets
# in the portfolio, backfill from portfolio inception date,
# and save a clean historical prices dataset.
# ============================================================

from pathlib import Path
import pandas as pd
import yfinance as yf

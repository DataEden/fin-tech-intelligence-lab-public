# %%
# ============================================================
# Financial Intelligence Lab
# 01_loaders_and_merge.ipynb 
#
# Purpose:
# Load local CSVs for portfolio snapshots, summary, and notes,
# clean them, and merge them into one analysis-ready DataFrame.
# ============================================================

from pathlib import Path
import pandas as pd

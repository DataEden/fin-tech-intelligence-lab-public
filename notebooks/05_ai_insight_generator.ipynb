# %%
# ============================================================
# Financial Intelligence Lab
# 05_ai_insight_generator.ipynb
#
# Purpose:
# Generate AI-assisted daily market commentary using:
# - daily portfolio summary
# - merged portfolio analysis
# - market notes
#
# Design goals:
# - compact prompts for cost efficiency
# - structured inputs from validated data
# - reusable output for blog/report workflows
# ============================================================

# imports
from pathlib import Path
from datetime import datetime
import json
import os

import pandas as pd
from dotenv import load_dotenv
from openai import OpenAI
